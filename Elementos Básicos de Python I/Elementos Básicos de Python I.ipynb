# %%
sexo = 'F'
beta_hcg = 10

# Verificando o sexo e o valor do beta-HCG
if sexo == 'M':
    print("Indivíduo do sexo masculino")
elif sexo == 'F':
    if beta_hcg > 5:
        print("Positivo - Paciente está grávida")
    else:
        print("Negativo - Paciente não está grávida")
